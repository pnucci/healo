# %% [markdown]
# <a href="https://colab.research.google.com/github/pnucci/healo/blob/main/package_kivymd_apps.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Packaging applications for android with buildozer
#
# ## Step 1: Install buildozer dependencies
#
# Run the following cell.

# %%
# !wget https://github.com/HeaTTheatR/KivyMD-data/raw/master/install-kivy-buildozer-dependencies.sh
# !chmod +x install-kivy-buildozer-dependencies.sh

# !./install-kivy-buildozer-dependencies.sh

# %% [markdown]
# ## Step 2: Install some updates and packages vital for packaging

# %%
# !sudo apt update
# !sudo apt install -y git zip unzip openjdk-8-jdk python3-pip autoconf libtool pkg-config zlib1g-dev libncurses5-dev libncursesw5-dev libtinfo5 cmake libffi-dev libssl-dev
# !pip install --upgrade Cython==0.29.19 virtualenv
# !sudo apt upgrade

# %% [markdown]
# ## Step 3: Create the spec file
#
# Run the command below, a file name buildozer.spec will be created. Double click the file to edit it.
# You can edit the app name, package name and so forth.
#
# Scroll down to requirements, make sure they look as follows:
# requirements = python3,kivy==2.0.0,https://github.com/kivymd/KivyMD/archive/master.zip,sdl2_ttf==2.0.15,pillow
#
# You can also add app permissions if your application requires special permissions.

# %%
# !buildozer init

# %% [markdown]
# ## Step 4: Upload the files
#
# Upload the files main.py and main.kv
# Click on the file icon to the left of the screen, right click and click upload.

# %% [markdown]
# ## Step 5: Run buildozer.
# Make sure to accept the terms and conditions. The process could take up to 15 minutes so be patient.

# %%
# !buildozer -v android debug
# Out:
# Streaming output truncated to the last 5000 lines.
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_21/python3/Lib/test/test_copy.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_21/python3/Lib/test/test_copyreg.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_21/python3/Lib/test/test_coroutines.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_21/python3/Lib/test/test_cprofile.py'...
# Compiling '/content/.buildozer/android/platform/build-armeabi-v7a/build/other_builds/python3/armeabi-v7a__ndk_target_21/python3/Lib/test/test_crashers.py'...
# ...

# %% [markdown]
# ## Step 6: Download the apk file.
#
# The apk file is saved in the bin folder, download it to your PC!
#
# Now return to the article if you need help figuring out how we can debug our application!
